# %%
import pandas as pd
df = pd.read_csv (r'results.csv')
df
# Out:
#      Unnamed: 0               0  \
# 0             0    LOT 1Closed
# 1             1    LOT 2Closed
# 2             2    LOT 3Closed
# 3             3    LOT 4Closed
# 4             4    LOT 5Closed
# ..          ...             ...
# 111         111  LOT 116Closed
# 112         112  LOT 117Closed
# 113         113  LOT 118Closed
# 114         114  LOT 119Closed
# 115         115  LOT 120Closed
#
#                                                      1  \
# 0    History of the Académie des Inscriptions et Be...
# 1                                  Medals of Louis XIV
# 2                       The Coronation of Alexander II
# 3                              Charming French almanac
# 4                                Books on Ancient Rome
# ..                                                 ...
# 111    The Natural History and Antiquities of Selborne
# 112                             Streetcar named Desire
# 113                                     The Genus Rosa
# ...

# %%
new = df['4'].str.split('-', 1, expand=True)
df['Min_Estimate'] = new[0]
df['Max_Estimate'] = new[1]
df.drop(columns =["4"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '4'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-c1b07fe87fd1> in <module>
# ...

# %%
df.head()
# Out:
#    Unnamed: 0             0  \
# 0           0  LOT 1Closed
# 1           1  LOT 2Closed
# 2           2  LOT 3Closed
# 3           3  LOT 4Closed
# 4           4  LOT 5Closed
#
#                                                    1  \
# 0  History of the Académie des Inscriptions et Be...
# 1                                Medals of Louis XIV
# 2                     The Coronation of Alexander II
# 3                            Charming French almanac
# 4                              Books on Ancient Rome
#
#                                        2         3               5  \
# 0          Count of Maurepas' copy, 1740  Estimate  Price Realised
# 1  Bound with royal arms of France, 1702  Estimate  Price Realised
# 2                    St Petersburg, 1856  Estimate  Price Realised
# 3                            Paris, 1788  Estimate  Price Realised
# 4                    8 works, 1587-1759.  Estimate  Price Realised
#
# ...

# %%
new = df['9'].str.split('|', 1, expand=True)
df['Date'] = new[0]
df['Type'] = new[1]
df.drop(columns =["9"], inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0             0  \
# 0           0  LOT 1Closed
# 1           1  LOT 2Closed
# 2           2  LOT 3Closed
# 3           3  LOT 4Closed
# 4           4  LOT 5Closed
#
#                                                    1  \
# 0  History of the Académie des Inscriptions et Be...
# 1                                Medals of Louis XIV
# 2                     The Coronation of Alexander II
# 3                            Charming French almanac
# 4                              Books on Ancient Rome
#
#                                        2         3               5  \
# 0          Count of Maurepas' copy, 1740  Estimate  Price Realised
# 1  Bound with royal arms of France, 1702  Estimate  Price Realised
# 2                    St Petersburg, 1856  Estimate  Price Realised
# 3                            Paris, 1788  Estimate  Price Realised
# 4                    8 works, 1587-1759.  Estimate  Price Realised
#
# ...

# %%
df
# Out:
#      Unnamed: 0               0  \
# 0             0    LOT 1Closed
# 1             1    LOT 2Closed
# 2             2    LOT 3Closed
# 3             3    LOT 4Closed
# 4             4    LOT 5Closed
# ..          ...             ...
# 111         111  LOT 116Closed
# 112         112  LOT 117Closed
# 113         113  LOT 118Closed
# 114         114  LOT 119Closed
# 115         115  LOT 120Closed
#
#                                                      1  \
# 0    History of the Académie des Inscriptions et Be...
# 1                                  Medals of Louis XIV
# 2                       The Coronation of Alexander II
# 3                              Charming French almanac
# 4                                Books on Ancient Rome
# ..                                                 ...
# 111    The Natural History and Antiquities of Selborne
# 112                             Streetcar named Desire
# 113                                     The Genus Rosa
# ...

# %%
#- if column conatins usd take the integer, else if 
# for date: split and convert to dateformat
